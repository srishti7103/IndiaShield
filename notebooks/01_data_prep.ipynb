# %% [markdown]
# # 01. Data Preparation and Cleaning
#
# This notebook documents the steps taken to clean and prepare raw military spending and arms transfer data for **IndiaShield**.

# %%
import pandas as pd
import numpy as np
import os

print("Libraries loaded successfully.")

# %% [markdown]
# ## 1. Load Military Expenditure Data
# SIPRI Military Expenditure data needs to be read from raw files (if available) or initialized via fallback dictionaries.

# %%
# Code template to load and check raw military spend data
raw_path = '../data/raw/sipri_milex.csv'
if os.path.exists(raw_path):
    df = pd.read_csv(raw_path)
    print("Loaded raw SIPRI file:", df.shape)
else:
    print("Raw file missing. Fallback initialized.")
